# %%
import pandas as pd

train_label = pd.read_csv("train_label.csv")

# %%
train_label
# Out:
#         Id Category
# 0        0     edge
# 1        1     edge
# 2        2     edge
# 3        3     edge
# 4        4     edge
# ...    ...      ...
# 5995  5995   spiral
# 5996  5996   spiral
# 5997  5997   spiral
# 5998  5998   spiral
# 5999  5999   spiral
#
# [6000 rows x 2 columns]

# %%
train_desc = pd.read_csv("train_desc_pca.csv")

# %%
train_desc
# Out:
#               0          1          2  ...        61        62        63
# 0     13.934082  -3.077109 -13.515020  ...  0.530720  0.171594 -0.322960
# 1     18.757893  -0.304454   1.757282  ...  1.700099 -0.001509  1.077432
# 2     -8.063476  -3.259291 -16.577340  ...  2.724299 -0.663966 -1.755266
# 3      3.128894  16.911400 -10.434631  ...  0.440074 -0.087064  1.925870
# 4    -15.744248  -1.022630   0.004898  ... -2.284629  0.672590 -0.606422
# ...         ...        ...        ...  ...       ...       ...       ...
# 5995 -12.293160 -10.322999   0.223454  ...  2.231260 -1.360051  0.204846
# 5996  22.010223   7.350494   9.103171  ... -0.953173 -0.307711  0.517690
# 5997  16.952154  12.396045  20.264088  ...  0.175051  0.573456  0.318759
# 5998  14.546743  -6.937125   8.490338  ... -0.231413  0.913135  1.661561
# 5999 -15.643326   5.735516   1.492304  ... -1.464624  0.800524  0.269107
#
# [6000 rows x 64 columns]

# %%
test_desc = pd.read_csv("test_desc_pca.csv")

# %%
test_desc
# Out:
#               0          1          2  ...        61        62        63
# 0    -14.238203 -15.670372 -12.266742  ... -0.757767 -1.793229 -1.617771
# 1    -11.216001  15.657775  -1.080561  ...  0.859141 -0.279321  0.024584
# 2     19.227375 -13.398582   6.344983  ... -0.533958  0.417801 -1.707941
# 3    -12.524920   9.557715  15.283616  ...  0.873334 -1.319784 -0.432190
# 4     15.702551   9.524783 -16.462688  ...  0.579105 -0.327169  0.806069
# ...         ...        ...        ...  ...       ...       ...       ...
# 1495   0.622085  25.971592   1.090095  ...  1.781143  0.192862  0.359355
# 1496   0.697014   8.985452  12.299419  ...  2.172651 -2.120108 -0.399652
# 1497   8.581366   8.363638 -16.734985  ...  0.075536 -0.296208 -1.123967
# 1498  20.707610  -0.125794   1.157218  ...  0.011236 -0.468396  1.609415
# 1499 -20.221289  -7.976724   4.306479  ... -0.047714  1.460051  0.700565
#
# [1500 rows x 64 columns]

# %%
X = train_desc
Y = train_label

# %%
Y = Y.iloc[0 : , 1]
Y
# Out:
# 0         edge
# 1         edge
# 2         edge
# 3         edge
# 4         edge
#          ...
# 5995    spiral
# 5996    spiral
# 5997    spiral
# 5998    spiral
# 5999    spiral
# Name: Category, Length: 6000, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
classle = LabelEncoder()


Y = classle.fit_transform(train_label['Category'].values)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train,Y_test = train_test_split(X,Y,test_size = 0.3, random_state = 0, stratify=Y)

# %%
  from sklearn.preprocessing import StandardScaler

  sc = StandardScaler()
  sc.fit(X_train)
  X_train = sc.transform(X_train)
  X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
Logit = LogisticRegression(C = 200,random_state=11)

l_1=Logit.fit(X_train, Y_train)
y_train_pred = Logit.predict(X_train)
y_test_pred = Logit.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_train,y_train_pred))  
print(accuracy_score(Y_test,y_test_pred))
# Out:
# 0.8014285714285714
# 0.7922222222222223

# %%
test_desc
# Out:
#               0          1          2  ...        61        62        63
# 0    -14.238203 -15.670372 -12.266742  ... -0.757767 -1.793229 -1.617771
# 1    -11.216001  15.657775  -1.080561  ...  0.859141 -0.279321  0.024584
# 2     19.227375 -13.398582   6.344983  ... -0.533958  0.417801 -1.707941
# 3    -12.524920   9.557715  15.283616  ...  0.873334 -1.319784 -0.432190
# 4     15.702551   9.524783 -16.462688  ...  0.579105 -0.327169  0.806069
# ...         ...        ...        ...  ...       ...       ...       ...
# 1495   0.622085  25.971592   1.090095  ...  1.781143  0.192862  0.359355
# 1496   0.697014   8.985452  12.299419  ...  2.172651 -2.120108 -0.399652
# 1497   8.581366   8.363638 -16.734985  ...  0.075536 -0.296208 -1.123967
# 1498  20.707610  -0.125794   1.157218  ...  0.011236 -0.468396  1.609415
# 1499 -20.221289  -7.976724   4.306479  ... -0.047714  1.460051  0.700565
#
# [1500 rows x 64 columns]

# %%
test_desc = sc.transform(test_desc)
guesses =Logit.predict(test_desc)

# %%
len(guesses)
# Out:
# 1500

# %%
guesses =classle.inverse_transform(guesses)

# %%
result = pd.DataFrame({'id':range(0,1500),'Category' : guesses})

# %%
result.to_csv("Result_try_2.csv",index= False)

# %%
submit = pd.read_csv("sample_submit.csv")

submit
# Out:
#         Id Category
# 0        0     none
# 1        1     none
# 2        2     none
# 3        3     none
# 4        4     none
# ...    ...      ...
# 1495  1495     none
# 1496  1496     none
# 1497  1497     none
# 1498  1498     none
# 1499  1499     none
#
# [1500 rows x 2 columns]

# %%
result
# Out:
#         id Category
# 0        0     edge
# 1        1   smooth
# 2        2   spiral
# 3        3   spiral
# 4        4     edge
# ...    ...      ...
# 1495  1495   spiral
# 1496  1496   spiral
# 1497  1497     edge
# 1498  1498   spiral
# 1499  1499   smooth
#
# [1500 rows x 2 columns]
